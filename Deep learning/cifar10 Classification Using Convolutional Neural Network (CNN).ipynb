# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import tensorflow as tf
# ----> 2 from tensorflow.keras import datasets, layers, models
#       3 import matplotlib.pyplot as plt
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'tensorflow.keras'

# %%
import pickle

# %%
#with open("C:\\Users\\Laptop\\Downloads\\archive (2)\\data.pickle", "rb") as f:
 #   loaded_data = pickle.load(f)

# %%
#print(loaded_data)
# Out:
# {'x_train': array([[[[-0.9765947 , -1.20274679, -1.12147945, ...,  0.37438191,
#            0.29918229,  0.24524932],
#          [-1.56983965, -1.80024453, -1.5686131 , ..., -0.09698351,
#           -0.14219787, -0.09743742],
#          [-1.45465895, -1.58628477, -1.14006269, ..., -0.15791148,
#           -0.11994925, -0.27264091],
#          ...,
#          [ 1.2673772 ,  1.20990938,  1.17946252, ...,  0.56839794,
#           -1.08849913, -1.13834655],
#          [ 0.81741582,  0.74594032,  0.95898125, ...,  0.92206276,
#           -0.44932719, -0.66834071],
#          [ 0.7534969 ,  0.64417231,  0.81629385, ...,  1.39452682,
#            0.38063594, -0.05608624]],
#
#         [[-1.01526525, -1.24341229, -1.23034536, ..., -0.05811958,
#           -0.14657607, -0.15640599],
#          [-1.59722613, -1.88453345, -1.79105393, ..., -0.66264337,
#           -0.72072694, -0.65786983],
#          [-1.54778089, -1.79227136, -1.52792336, ..., -0.71245746,
# ...

# %%
(X_train, y_train), (X_test,y_test) = datasets.cifar10.load_data()

# %%
print(tf.__version__)
# Out:
# 2.9.1

# %%
x_train.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 x_train.shape
#
# NameError: name 'x_train' is not defined

# %%
y_train.shape
# Out:
# (50000, 1)

# %%
y_train[:4]
# Out:
# array([[6],
#        [9],
#        [9],
#        [4]], dtype=uint8)

# %%
y_test[:4]
# Out:
# array([[3],
#        [8],
#        [8],
#        [0]], dtype=uint8)

# %%
#y_train and y_test is a 2D array, for our classification having 1D array is good enough. 
#so we will convert this to now 1D array
y_train = y_train.reshape(-1,)
y_test= y_test.reshape(-1,)
print(y_test[:3])
# Out:
# [3 8 8]

# %%
classes = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

# %%
#visualize images, lets make a function
def plot_sample(X, y, index):
    plt.figure(figsize = (15,2))
    plt.imshow(X[index])
    plt.xlabel(classes[y[index]])

# %%
plot_sample(X_train, y_train, 67)

# %%
plot_sample(X_train, y_train, 4)

# %%
#Normalizing the training data
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
#Now let us build a convolutional neural network to train our images

# %%
cnn = models.Sequential([
    layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)),
    layers.MaxPooling2D((2, 2)),
    
    layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])
