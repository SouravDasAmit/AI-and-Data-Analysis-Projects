# %%
#Introduction to seaborn
#Seaborn is a stastical default library
#It has beautiful default styles
#It also is designed to work very well with pandas dataframework

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
tips= sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.displot(tips["total_bill"])

# %%
sns.displot(tips["total_bill"], kde= True, bins=100)

# %%
sns.jointplot(x="total_bill", y="tip",data=tips)

# %%
sns.jointplot(x="total_bill", y="tip",data=tips, kind="hex")

# %%
sns.jointplot(x="total_bill", y="tip",data=tips, kind="reg")

# %%
sns.jointplot(x="total_bill", y="tip",data=tips, kind="kde")

# %%
sns.pairplot(tips, hue="sex", palette= "coolwarm") #palette is colour combination in seaborn

# %%
sns.rugplot(tips["total_bill"], height=.3)
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
#how to make kdp
np.random.seed(101)
x = np.random.normal(0, 1, size=20)
plt.figure(figsize=(4,2),dpi=200)
sns.rugplot(x, color="darkblue", linewidth=4)
# Out:
# <AxesSubplot:>

# %%
from scipy import stats
plt.figure(figsize=(8,4),dpi=200)
bandwidth = x.std() * x.size ** (-0.001)
support = np.linspace(-5, 5, 100)

kernels = []

plt.figure(figsize=(6,3))

for x_i in x:

    kernel = stats.norm(x_i, bandwidth).pdf(support)
    kernels.append(kernel)
    plt.plot(support, kernel, color="lightblue")

sns.rugplot(x, color="darkblue", linewidth=4);

# %%
#plt.figure(figsize=(8,4),dpi=200)
from scipy.integrate import trapz
plt.figure(figsize=(5,3))
density = np.sum(kernels, axis=0)
density /= trapz(density, support)
plt.plot(support, density);
sns.rugplot(x, color="darkblue", linewidth=4);

# %%
np.sum(kernels, axis=0)
# Out:
# array([0.01245592, 0.0159017 , 0.02016286, 0.02539473, 0.03177332,
#        0.03949629, 0.04878368, 0.05987832, 0.07304594, 0.08857492,
#        0.1067757 , 0.12797984, 0.15253866, 0.18082163, 0.21321428,
#        0.25011578, 0.2919362 , 0.33909314, 0.3920081 , 0.4511021 ,
#        0.51679082, 0.5894789 , 0.66955354, 0.75737721, 0.85327938,
#        0.95754742, 1.07041639, 1.1920581 , 1.3225692 , 1.46195869,
#        1.61013486, 1.76689202, 1.93189721, 2.10467733, 2.28460713,
#        2.47089847, 2.66259151, 2.85854853, 3.05745094, 3.2578005 ,
#        3.45792529, 3.65599143, 3.850021  , 4.0379169 , 4.21749472,
#        4.38652169, 4.54276226, 4.68402935, 4.80824002, 4.91347357,
#        4.99803002, 5.06048628, 5.09974724, 5.11508909, 5.10619223,
#        5.07316144, 5.01653175, 4.93725895, 4.83669453, 4.71654588,
#        4.57882334, 4.42577632, 4.25982185, 4.08346876, 3.89924146,
#        3.70960698, 3.51690863, 3.32330936, 3.130747  , 2.94090288,
# ...

# %%
len(kernels)
# Out:
# 20

# %%
# catagorical plot

# %%
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
fig= plt.figure(figsize=(4, 3))
sns.barplot(x="sex", y="total_bill", data= tips)
#plt.show()
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
import numpy as np

# %%
fig= plt.figure(figsize=(4, 3))
sns.barplot(x="sex", y="total_bill", data= tips, estimator=np.std)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
#count plot work just one catagorica colum 
plt.figure(figsize=(4, 3))
sns.countplot(x= "sex", data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
fig= plt.figure(figsize=(4, 3))
sns.boxenplot(x="day", y="total_bill", data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
#insert a categorical coloum into boxplot, 
fig= plt.figure(figsize=(4, 3))
sns.boxenplot(x="day", y="total_bill", data=tips, hue="smoker")
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
fig= plt.figure(figsize=(4, 3))
sns.violinplot(x="day", y="total_bill", data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
fig= plt.figure(figsize=(4, 3))
sns.violinplot(x="day", y="total_bill", data=tips, hue="sex", split=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
fig= plt.figure(figsize=(4, 3))
sns.stripplot(x="day", y="total_bill", data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
fig= plt.figure(figsize=(4, 3))
sns.stripplot(x="day", y="total_bill", data=tips,jitter=True, hue="sex")
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
#you can combine two graph 
fig= plt.figure(figsize=(4, 3))
sns.violinplot(x="day", y="total_bill", data=tips)
sns.stripplot(x="day", y="total_bill", data=tips, jitter=True, hue="sex", palette='dark:black')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
fig= plt.figure(figsize=(6, 4))
sns.swarmplot(x="day", y="total_bill", data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# matrix plots

# %%
#import mathplotlib.
# %matplotlib inline
flights= sns.load_dataset("flights")

# %%
flights.head(3)
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132

# %%
ts=tips.corr()
ts
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
# if you want to every coloum and row value inside figure then set annot= true
#and want to change color then set cmap value
plt.figure(figsize=(5, 3))
sns.heatmap(ts, annot=True, cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
fp=flights.pivot_table(index="month", columns="year", values="passengers")
fp.head(3)
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419

# %%
plt.figure(figsize=(5,3)) 
sns.heatmap(fp, linecolor="white", lw=1)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
#plt.figure(figsize=(5,3)) 
sns.clustermap(fp, figsize=(4,3))

# %%
#Grids

# %%
iris= sns.load_dataset("iris")
iris.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
iris["species"].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
g= sns.PairGrid(iris)
g.map_diag(sns.histplot)
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot)

# %%
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
print(tips["time"].unique())
tips["smoker"].unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']
# ['No', 'Yes']
# Categories (2, object): ['Yes', 'No']

# %%
gr= sns.FacetGrid(data= tips, col="time", row="smoker")
gr.map(plt.scatter, "total_bill", "tip")

# %%
#regression plot

# %%
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
sns.lmplot(x= "total_bill", y="tip", data=tips, height=3, aspect=1.4)

# %%
sns.lmplot(x= "total_bill", y="tip", data=tips, hue="sex", height=3, aspect=1.4)

# %%
sns.lmplot(x= "total_bill", y="tip", data=tips, hue="sex", markers=["o","v"], scatter_kws={"s": 100}, height=3, aspect=1.4)

# %%
sns.lmplot(x= "total_bill", y="tip", data=tips, col="sex", height=3, aspect=1.1)

# %%
sns.lmplot(x= "total_bill", y="tip", data=tips, col="sex", row="time", height=2, aspect=1.1)

# %%
sns.lmplot(x= "total_bill", y="tip", data=tips, col="day", hue="sex", height=3, aspect=1.1)

# %%
# graaph color and style

# %%
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
#you can set differenr perameter to see parametes
plt.figure(figsize=(5,2))
sns.set_style("darkgrid")
sns.countplot(x="sex", data= tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
plt.figure(figsize=(5,2))
sns.set_style("ticks")
sns.countplot(x="sex", data= tips)
#sns.despine(left=True, top=True) #to remove border
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
plt.figure(figsize=(5,2))
sns.set_style("ticks")
sns.countplot(x="sex", data= tips)
sns.despine() #to remove border default value set left and button

# %%
plt.figure(figsize=(5,2))
sns.set_context("talk", font_scale=1) 
#you can change frobt size and style see its parameter for other optoin
sns.countplot(x="sex", data= tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
#you can use more color map you x
sns.lmplot(x="total_bill", y="tip", data=tips, hue="sex", palette="seismic")
